# %% [markdown]
# # W2. Probability
#  ict 융합학부 20232357 임준석

# %% [markdown]
# - 문제
#
# 어떤 이커머스 플랫폼의 방문자는 접속 기기 타입에 따라 ① PC 사용자(10%), ② 모바일 앱 사용자(60%), ③ 모바일 웹 사용자(30%) 등 3개 그룹으로 나뉨
#
# 각 그룹별 사용자가 접속 후 실제 제품을 구매할 확률은 다음과 같음
#
# - ① PC 사용자 그룹: 0.8
# - ② 모바일 앱 사용자 그룹: 0.2
# - ③ 모바일 웹 사용자 그룹: 0.5
#
# 이때 구매한 사람을 한명 골랐을 때 어느 플랫폼을 사용했을지 통계적으로 추론해보자

# %% [markdown]
# 1. 프롬프트 작성 과정

# %% [markdown]
# 2. 코드

# %%
def validate_priors(priors):
    total = sum(priors.values())
    if total != 1:
        raise ValueError(f"사전확률의 합이 1이 아닙니다: {total}")

# %%
def joint_probabilities(priors, likelihoods):
    """곱셈법칙 P(A_i ∩ B) = P(A_i) * P(B | A_i)"""
    return {k: priors[k] * likelihoods[k] for k in priors}

# %%
def total_probability(joint):
    """전체확률 P(B) = Σ P(A_i ∩ B)"""
    return sum(joint.values())

# %%
def posterior_probabilities(priors, likelihoods):
    """P(A_i | B) = P(A_i ∩ B) / P(B)"""
    validate_priors(priors)
    joint = joint_probabilities(priors, likelihoods)
    p_b = total_probability(joint)
    return {k: v / p_b for k, v in joint.items()}

# %%
def map_estimate(posteriors):
    """사후확률이 가장 큰 플랫폼 (MAP 추정)"""
    return max(posteriors, key=posteriors.get)

# %%
def main():
    priors = {"PC": 0.1, "모바일 앱": 0.6, "모바일 웹": 0.3}
    likelihoods = {"PC": 0.8, "모바일 앱": 0.2, "모바일 웹": 0.5}

    joint = joint_probabilities(priors, likelihoods)
    p_b = total_probability(joint)
    posteriors = posterior_probabilities(priors, likelihoods)

    print("=" * 50)
    print(" 베이즈 정리: P(플랫폼 | 구매)")
    print("=" * 50)
    print(f"{'플랫폼':<8}{'P(A)':>10}{'P(B|A)':>10}{'P(A∩B)':>10}{'P(A|B)':>12}")
    print("-" * 50)
    for k in priors:
        print(f"{k:<8}{priors[k]:>10.2f}{likelihoods[k]:>10.2f}"
              f"{joint[k]:>10.4f}{posteriors[k]:>12.4f}")
    print("-" * 50)
    print(f"전체 구매 확률 P(B) = {p_b:.4f}")
    print(f"사후확률 합계       = {sum(posteriors.values()):.4f}")

    best = map_estimate(posteriors)
    print(f"\n▶ 결론: 구매자는 '{best}' 사용자였을 확률이 가장 높다 (약 {posteriors[best]:.2%})")

# %%
if __name__ == "__main__":
    main()
# Out:
# ==================================================
#  베이즈 정리: P(플랫폼 | 구매)
# ==================================================
# 플랫폼           P(A)    P(B|A)    P(A∩B)      P(A|B)
# --------------------------------------------------
# PC            0.10      0.80    0.0800      0.2286
# 모바일 앱         0.60      0.20    0.1200      0.3429
# 모바일 웹         0.30      0.50    0.1500      0.4286
# --------------------------------------------------
# 전체 구매 확률 P(B) = 0.3500
# 사후확률 합계       = 1.0000
#
# ▶ 결론: 구매자는 '모바일 웹' 사용자였을 확률이 가장 높다 (약 42.86%)

# %% [markdown]
# 3. 고찰
#
# 왜 이 프롬프트를 사용했는가?
# LLM의 답변은 정확했는가?
# 코드의 결과를 어떻게 검증했는가?
# 코드에서 이해하기 어려웠던 부분은 무엇인가?
# LLM의 코드에서 수정하거나 보완한 부분은 무엇인가?
# 강의에서 배운 개념이 실제 코드에 어떻게 적용되었는가?
# 이 코드의 한계와 개선 방법은 무엇인가?
