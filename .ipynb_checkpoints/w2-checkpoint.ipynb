# %% [markdown]
# # W2. Probability
#  ict 융합학부 20232357 임준석

# %% [markdown]
# #### 문제
#
# 어떤 이커머스 플랫폼의 방문자는 접속 기기 타입에 따라 ① PC 사용자(10%), ② 모바일 앱 사용자(60%), ③ 모바일 웹 사용자(30%) 등 3개 그룹으로 나뉨
#
# 각 그룹별 사용자가 접속 후 실제 제품을 구매할 확률은 다음과 같음
#
# - ① PC 사용자 그룹: 0.8
# - ② 모바일 앱 사용자 그룹: 0.2
# - ③ 모바일 웹 사용자 그룹: 0.5
#
# 이때 구매한 사람을 한명 골랐을 때 어느 플랫폼을 사용했을지 통계적으로 추론해보자

# %% [markdown]
# #### 1. 프롬프트 작성 과정
#
# - 문제와 pdf를 같이 주면서 이 문제를 해결할 수 있는 방법과, 코드 작성에 도움을 받았다.
# - 입력 토큰 3.6k, 출력토큰 10.7k로 조회되나, 여러번 끊어가며 사용해 사용량이 정확하진 않음.

# %% [markdown]
# #### 2. 코드

# %%
def validate_priors(priors):
    total = sum(priors.values())
    if total != 1:
        raise ValueError(f"사전확률의 합이 1이 아닙니다: {total}")



def joint_probabilities(priors, likelihoods):  # ppt 10페이지 참고
    """곱셈법칙 P(A ∩ B) =  P(A | B) * P(B) = P(A) * P(B | A) """
    return {k: priors[k] * likelihoods[k] for k in priors}



def total_probability(joint):  # ppt 14페이지 참고
    """전체확률 P(B) = Σ P(B | A) * P(A) = Σ P(A ∩ B)"""
    return sum(joint.values())



def posterior_probabilities(priors, likelihoods):  # ppt 11, 15페이지 참고
    """베이즈 정리 P(A | B) = P(A ∩ B) / P(B)"""
    validate_priors(priors)
    joint = joint_probabilities(priors, likelihoods)
    p_b = total_probability(joint)
    return {k: v / p_b for k, v in joint.items()}



def max_estimate(posteriors):
    """사후확률이 가장 큰 플랫폼"""
    return max(posteriors, key=posteriors.get)



def main():
    priors = {"PC": 0.1, "App": 0.6, "Web": 0.3}
    likelihoods = {"PC": 0.8, "App": 0.2, "Web": 0.5}

    joint = joint_probabilities(priors, likelihoods)
    p_b = total_probability(joint)
    posteriors = posterior_probabilities(priors, likelihoods)

    print("=" * 50)
    print(" 베이즈 정리: P(플랫폼 | 구매)")
    print("=" * 50)
    print(f"{'Platform':<8}{'P(A)':>10}{'P(B|A)':>10}{'P(A∩B)':>10}{'P(A|B)':>12}")
    print("-" * 50)
    for k in priors:
        print(f"{k:<8}{priors[k]:>10.2f}{likelihoods[k]:>10.2f}{joint[k]:>10.4f}{posteriors[k]:>12.4f}")
    print("-" * 50)
    print(f"전체 구매 확률 P(B) = {p_b:.4f}")
    print(f"사후확률 합계       = {sum(posteriors.values()):.4f}")

    best = max_estimate(posteriors)
    print(f"\n▶ 결론: 구매자는 '{best}' 사용자였을 확률이 가장 높다 (약 {posteriors[best]:.2%})")



if __name__ == "__main__":
    main()
# Out:
# ==================================================
#  베이즈 정리: P(플랫폼 | 구매)
# ==================================================
# Platform      P(A)    P(B|A)    P(A∩B)      P(A|B)
# --------------------------------------------------
# PC            0.10      0.80    0.0800      0.2286
# App           0.60      0.20    0.1200      0.3429
# Web           0.30      0.50    0.1500      0.4286
# --------------------------------------------------
# 전체 구매 확률 P(B) = 0.3500
# 사후확률 합계       = 1.0000
#
# ▶ 결론: 구매자는 'Web' 사용자였을 확률이 가장 높다 (약 42.86%)

# %% [markdown]
# #### 3. 고찰
#
# 이번 확률에서의 응용 과제에서는 베이즈 정리를 이용한 구매가 발생했을 때 구매자가 어느 플랫폼을 사용해서 구매했는지를 추론을 하는것이다. 처음에 문제만 봤을 때는 막연하게 PC를 통해서 구매한 구매자가 제일 많길래 제일 많은 확률을, 앱을 통해서 구매한 구매자는 플랫폼 접속량은 많지만, 구매 확률이 20%이길래 제일 낮을거라고 예상하고 계산을 했다. 계산을 위해 코드를 작성하는 중에는 LLM을 이용해 작성했지만, LLM을 이용하는 것도 내가 원하는 것을 정확히 전달할 수 있는 능력과 내가 LLM이 완성한 코드를 이해하지 못한다면 오류가 있어도 찾아내지 못하기 때문에 코드를 이해할 수 있도록 코드 리딩 능력을 키울 필요가 있다는 것을 알게 되었다. 코드 작성을 끝내고, 코드 실행 결과를 보아, Web, App, PC 순으로 구매 확률이 높은 것을 보고 구매 확률만 중요하다는 것은 아니라는 것을 알게되었고, 베이즈 정리가 관찰한 결과로부터 원인을 추론하는 도구임을 알게 되었다.
